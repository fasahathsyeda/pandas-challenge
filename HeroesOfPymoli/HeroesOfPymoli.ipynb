# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
purchase_data.count()
purchase_data.shape
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_unique_players=purchase_data["SN"].unique()
total_unique_players
Unique_players_df=pd.DataFrame({"Total Players": [len(total_unique_players)]})
Unique_players_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items=purchase_data["Item Name"].unique()
len(unique_items)
average_price=purchase_data["Price"].mean()
average_price
number_purchases=purchase_data["Item ID"].count()
number_purchases
total_revenue=purchase_data["Price"].sum()
total_revenue
pd.DataFrame({"Number of Unique Items" : [len(unique_items)],"Average Price" : [ str('${:.2f}'.format(average_price))],"Number of Purchases" : [number_purchases],"Total Revenue" : [ str('${:.2f}'.format(total_revenue))]})
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
duplicate_drop= purchase_data.drop_duplicates(["SN"])
duplicate_drop.shape
gender_group_unique = duplicate_drop.groupby(["Gender"])
gender_group_unique.head(10)
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 7              7    Iskjaskst81   20                   Male      162
# 8              8      Undjask33   22                   Male       21
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 10            10      Inguron55   23                   Male       95
# 15            15      Lisassa64   21                 Female       98
# 18            18      Reunasu60   22                 Female       82
# ...

# %%
gender_demographics= pd.DataFrame()
gender_demographics["Gender"]=gender_group_unique["Gender"].count()
gender_demographics
gender_demographics = gender_demographics.rename(columns={"Gender": "Total Count"}).reset_index()
gender_demographics
gender_demographics["Percentage of Players"]=(gender_demographics["Total Count"]/len(total_unique_players)).map("{:.2%}".format)
gender_demographics.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119" ><thead>    <tr>        <th class="col_heading level0 col0" >Gender</th>        <th class="col_heading level0 col1" >Total Count</th>        <th class="col_heading level0 col2" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119row0_col0" class="data row0 col0" >Female</td>
#                         <td id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119row0_col1" class="data row0 col1" >81</td>
#                         <td id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119row0_col2" class="data row0 col2" >14.06%</td>
#             </tr>
#             <tr>
#                                 <td id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119row1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_af5c4d1d_ebc2_11ea_8fcf_92af78616119row1_col1" class="data row1 col1" >484</td>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_group=purchase_data.groupby(["Gender"])
gender_group.head()
gender_group["Purchase ID"].count()
gender_group["Price"].mean()
#gender_group["Purchase ID"].count()
#gender_group["Gender"].count()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
purchase_analysis_gender=pd.DataFrame()


purchase_analysis_gender["Purchase Count"]=gender_group["Purchase ID"].count()

Total_purchase=gender_group["Price"].sum()
purchase_analysis_gender["Average Purchase Price"]=(gender_group["Price"].mean()).map("${:.2f}".format)
purchase_analysis_gender["Total Purchase Value"]=(gender_group["Price"].sum()).map("${:.2f}".format)
purchase_analysis_gender["Avg Total Purchase per Person"]=(Total_purchase/gender_group_unique["Gender"].count()).map("${:.2f}".format)

#purchase_analysis_gender=purchase_analysis_gender.rename(columns={"Purchase ID": "Purchase Count"})
#purchase_analysis_gender
#Total_purchase=gender_group["Price"].sum()
#purchase_analysis_gender["Average Purchase Price"]=(Total_purchase/gender_group["Purchase ID"].count()).map("${:.2f}".format)
#purchase_analysis_gender["Total Purchase Value"]=(Total_purchase).map("${:.2f}".format)
#purchase_analysis_gender["Avg Total Purchase per Person"]=(Total_purchase/gender_group["Gender"].count()).map("${:.2f}".format)
purchase_analysis_gender
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
